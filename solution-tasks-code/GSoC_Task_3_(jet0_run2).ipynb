# %% [markdown]
# # ***Graph Neural Networks for End-to-End Particle Identification with the CMS Experiment***
# ### *written by Khalid Bagus Pratama Darmadi, S.Si (Khalid); Papua, Indonesia*
# *for ML4SCI on Google Summer of Code 2023*

# %% [markdown]
# Common Task 3. Deep Learning based Quark-Gluon Classification
# Datasets:
#
# > https://cernbox.cern.ch/index.php/s/hqz8zE7oxyPjvsL
#
#
# Description: 125x125 matrices (three channel images) for two classes of particles quarks and gluons impinging on a calorimeter.
# For a description of 1st dataset please refer to the link provided for the dataset.
#
# > Choose 2 Graph-based architectures of your choice to classify jets as being quarks or gluons. Provide a description on what considerations you have taken to project this point-cloud dataset to a set of interconnected nodes and edges.
#
# > Discuss the resulting performance of the 2 chosen architectures.
#
# Please use a Convolutional Neural Network (CNN) architecture of your choice to achieve the highest possible classification on this dataset (in your preferred choice of framework for example: Tensorflow/Keras or Pytorch). Please provide a Jupyter notebook that shows your solution.

# %% [markdown]
# # **Solution:**
#
# ***(From 3 separate datasets available, here we used the jet0_run2)***
#
# For this task, here is the model description for classifying whether the output would be a quark or a gluon, with features X_jets, mean transverse momentum and mass. We are using the same preprocessed data as Task 2 (normalization), then with the generation of graph with edges to be used for training the model.
#
# This graph-based architecture model was designed for purpose in effectively learns complex patterns from the graph representation of the input data, which includes Laplacian and Hessian features and additional features like mean transverse momentum and mass. The combination of GATConv and ChebConv layers allows the model to efficiently learn spatially localized patterns on the graph and consider the importance of neighboring nodes. The global average pooling, dense, and dropout layers help to create a robust classifier for quark-gluon classification.
#
# 1. Data preprocessing and graph creation
#
#
# > The create_graph_from_features function creates a graph using Laplacian and Hessian features, along with additional features (mean transverse momentum and mass). You add edges to the graph based on k-nearest neighbors and Delaunay triangulation.
#
# 2. Spektral Graph creation
#
# > The create_spektral_graph function takes the NetworkX graph and converts it into a Spektral Graph object, which includes the node attributes and adjacency matrix.
#
# 3. Jet Classifier
#
# > *   Input layers: Two separate input layers for the node features (X) and adjacency matrix (A).
# *   GATConv layers: Three GATConv layers with 32, 64, and 128 filters, and 4 attention heads each. These layers help the model learn different representations of the input graph while considering the importance of neighboring nodes during the learning process.
# *   ChebConv layers: Three ChebConv layers with 128, 64, and 32 filters, and K=2 (Chebyshev order). ChebConv layers are spectral convolutional layers that efficiently learn spatially localized patterns on the graph. These layers help the model learn more complex patterns in the graph representation of the input data.
# *   GlobalAvgPool layer: This layer computes the average of the node features, creating a global feature vector that represents the entire graph.
# *   Dense and Dropout layers: Two dense layers with GELU and ReLU activation functions, respectively, learn higher-level abstractions of the global feature vector. Dropout layers (with a rate of 0.5) are used to prevent overfitting.
#
# 4. Output layer
#
# > *   The final dense layer with one unit and a sigmoid activation function produces a probability value between 0 and 1, representing the likelihood of the input belonging to the positive class (either quark or gluon).

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split

# %%
import pyarrow.parquet as pq

def save_data_batches(file_path, output_folder, batch_size=2267):
    os.makedirs(output_folder, exist_ok=True)
    
    file_name = os.path.basename(file_path)
    prefix = file_name.split('.')[0]
    
    parquet_file = pq.ParquetFile(file_path)
    
    for i, batch in enumerate(parquet_file.iter_batches(batch_size=batch_size)):
        batch_df = batch.to_pandas()
        output_file_name = f"{prefix}_batch_{i+1}.parquet"
        output_file_path = os.path.join(output_folder, output_file_name)
        batch_df.to_parquet(output_file_path)

data_path = "/content/drive/MyDrive/GSoC/tasks_2_and_3"
file_names = [
    "QCDToGGQQ_IMGjet_RH1all_jet0_run0_n36272.test.snappy.parquet",
    "QCDToGGQQ_IMGjet_RH1all_jet0_run1_n47540.test.snappy.parquet",
    "QCDToGGQQ_IMGjet_RH1all_jet0_run2_n55494.test.snappy.parquet"
]

for file_name in file_names:
    file_path = os.path.join(data_path, file_name)
    output_folder = os.path.join(data_path, "batches", file_name.split('.')[0])
    save_data_batches(file_path, output_folder)

# %%
# Assign folder containing the batch files
batch_folder = "/content/drive/MyDrive/GSoC/tasks_2_and_3/batches/QCDToGGQQ_IMGjet_RH1all_jet0_run2_n55494"

batch_file = os.path.join(batch_folder, "QCDToGGQQ_IMGjet_RH1all_jet0_run2_n55494_batch_1.parquet")
df_batch = pd.read_parquet(batch_file)

# %%
import matplotlib.pyplot as plt

X_jets = np.stack([
    np.array(
        [item for sublist1 in x for sublist2 in sublist1 for item in sublist2], 
        dtype=np.float32
    ).reshape(len(x), len(x[0]), len(x[0][0])) 
    for x in df_batch['X_jets'].values
])

index = 0
image = X_jets[index]

plt.imshow(image[1], cmap='GnBu')  # Display the first layer of the 3D array
plt.colorbar()
plt.title(f"Label: {df_batch.iloc[index]['y']}")
plt.show()

# %%
index = 0
image = X_jets[index]
label = df_batch.iloc[index]['y']
label_str = "Quark" if label == 0.0 else "Gluon"

# Display each layer separately
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

im0 = ax[0].imshow(image[0], cmap='GnBu')
ax[0].set_title("Layer 0")
fig.colorbar(im0, ax=ax[0], fraction=0.046, pad=0.04)

im1 = ax[1].imshow(image[1], cmap='GnBu')
ax[1].set_title("Layer 1")
fig.colorbar(im1, ax=ax[1], fraction=0.046, pad=0.04)

im2 = ax[2].imshow(image[2], cmap='GnBu')
ax[2].set_title("Layer 2")
fig.colorbar(im2, ax=ax[2], fraction=0.046, pad=0.04)

# Add a single title above all subplots
fig.suptitle(f"Label: {label_str}", fontsize=16, y=1.00)

plt.tight_layout()
plt.show()

# %%
# Locate extracted X_jets parquets data
batch_folder = "/content/drive/MyDrive/GSoC/tasks_2_and_3/batches/QCDToGGQQ_IMGjet_RH1all_jet0_run2_n55494"
x_jets_folder = os.path.join(batch_folder, "X_jets")

# Read and concatenate all the saved X_jets parquet files
X_jets_list = []

for i in range(1, 9):  # There are 25 batches in this folder, but let's just use 8
    x_jets_batch_file = os.path.join(x_jets_folder, f"X_jets_batch_{i}.parquet")
    X_jets_batch = pd.read_parquet(x_jets_batch_file).values
    X_jets_list.append(X_jets_batch.reshape(-1, 125, 125, 3))

X_jets_combined = np.concatenate(X_jets_list, axis=0)

del X_jets_list, x_jets_batch_file, X_jets_batch

# Combine all the pt, m0, and y values from the original dataframes, and we are only using 7 batches
df_all_batches = pd.concat([pd.read_parquet(os.path.join(batch_folder, f"QCDToGGQQ_IMGjet_RH1all_jet0_run2_n55494_batch_{i}.parquet")) for i in range(1, 9)], ignore_index=True)
pt_m0_all = df_all_batches[['pt', 'm0']].values
y_all = df_all_batches['y'].values

del df_all_batches

# %%
import numpy as np
import cv2
from skimage import feature
from skimage.feature import peak_local_max
from skimage.segmentation import felzenszwalb
import networkx as nx
import json

def laplacian_blob_detector(image, sigma=1.0):
    # Convert the image to a floating-point format
    image = image.astype(np.float32)

    # Apply Laplacian of Gaussian (LoG) filter
    log_image = cv2.GaussianBlur(image, (0, 0), sigma)
    log_image = cv2.Laplacian(log_image, cv2.CV_32F)

    # Find local maxima in the filtered image
    maxima = peak_local_max(log_image, min_distance=1, threshold_abs=0.05, exclude_border=False)

    return maxima

def hessian_blob_detector(image, sigma=1.0):
    # Apply Hessian matrix
    hessian_matrix = feature.hessian_matrix(image, sigma)

    # Compute the eigenvalues of the Hessian matrix
    eigenvalues = feature.hessian_matrix_eigvals(hessian_matrix)

    # Find local maxima in the response function
    local_maxima = feature.peak_local_max(eigenvalues)

    return local_maxima

def graph_based_segmentation(image, scale=100, sigma=0.5, min_size=50):
    # Apply Felzenszwalb-Huttenlocher algorithm for graph-based segmentation
    segments = felzenszwalb(image, scale=scale, sigma=sigma, min_size=min_size)

    return segments

def preprocess_jet_data(jet_images, additional_features, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    for idx, image in enumerate(jet_images):
        # Extract features using Laplacian-Blob Detector
        laplacian_features = [laplacian_blob_detector(layer).tolist() for layer in image]

        # Extract features using Hessian-Blob Detector
        hessian_features = [hessian_blob_detector(layer).tolist() for layer in image]

        # Perform graph-based segmentation on each layer
        segmented_images = [graph_based_segmentation(layer).tolist() for layer in image]

        # Save the preprocessed data to a parquet file
        df = pd.DataFrame({'features': [json.dumps((laplacian_features, hessian_features, segmented_images))],
                   'additional_features': [additional_features[idx]]})
        df.to_parquet(os.path.join(output_folder, f'preprocessed_data_{idx}.parquet'))
        del laplacian_features, hessian_features, segmented_images, df

# %%
# Preprocess the data
output_folder = '/content/drive/MyDrive/GSoC/task_3/preprocessed_data/jet0_run2_preprocessed_data'
preprocess_jet_data(X_jets_combined, pt_m0_all, output_folder)

# %%
num_images = len(X_jets_combined)
del X_jets_combined, pt_m0_all
print(f'There should be a total of {num_images} images.')
# Out:
# There should be a total of 18136 images.

# %%
# Read and concatenate all the saved X_jets parquet files
import json

output_folder = '/content/drive/MyDrive/GSoC/task_3/preprocessed_data/jet0_run2_preprocessed_data'
preprocessed_data = []

# List for storing non-skipped batches of data because of google drive crash
processed_indices = []

for idx in range(num_images):
    parquet_file = os.path.join(output_folder, f'preprocessed_data_{idx}.parquet')
    if os.path.exists(parquet_file):
        try:
            df = pd.read_parquet(parquet_file)
            print(f'Reading and appending preprocessed_data_{idx}.parquet')
            preprocessed_data.append((json.loads(df['features'][0]),
                                      df['additional_features'][0]))
            processed_indices.append(idx)
        except Exception as e:
            print(f'Error while processing preprocessed_data_{idx}.parquet: {e}')
            continue
    else:
        print(f'Skipping preprocessed_data_{idx}.parquet as it does not exist')

# Get the corresponding labels
y_processed = y_all[processed_indices]
# Out:
# Streaming output truncated to the last 5000 lines.
# Reading and appending preprocessed_data_13136.parquet
# Reading and appending preprocessed_data_13137.parquet
# Reading and appending preprocessed_data_13138.parquet
# Reading and appending preprocessed_data_13139.parquet
# Reading and appending preprocessed_data_13140.parquet
# Reading and appending preprocessed_data_13141.parquet
# Reading and appending preprocessed_data_13142.parquet
# Reading and appending preprocessed_data_13143.parquet
# Reading and appending preprocessed_data_13144.parquet
# Reading and appending preprocessed_data_13145.parquet
# Reading and appending preprocessed_data_13146.parquet
# Reading and appending preprocessed_data_13147.parquet
# Reading and appending preprocessed_data_13148.parquet
# Reading and appending preprocessed_data_13149.parquet
# Reading and appending preprocessed_data_13150.parquet
# Reading and appending preprocessed_data_13151.parquet
# Reading and appending preprocessed_data_13152.parquet
# Reading and appending preprocessed_data_13153.parquet
# Reading and appending preprocessed_data_13154.parquet
# Reading and appending preprocessed_data_13155.parquet
# Reading and appending preprocessed_data_13156.parquet
# Reading and appending preprocessed_data_13157.parquet
# Reading and appending preprocessed_data_13158.parquet
# Reading and appending preprocessed_data_13159.parquet
# Reading and appending preprocessed_data_13160.parquet
# Reading and appending preprocessed_data_13161.parquet
# Reading and appending preprocessed_data_13162.parquet
# Reading and appending preprocessed_data_13163.parquet
# Reading and appending preprocessed_data_13164.parquet
# Reading and appending preprocessed_data_13165.parquet
# Reading and appending preprocessed_data_13166.parquet
# Reading and appending preprocessed_data_13167.parquet
# Reading and appending preprocessed_data_13168.parquet
# Reading and appending preprocessed_data_13169.parquet
# Reading and appending preprocessed_data_13170.parquet
# Reading and appending preprocessed_data_13171.parquet
# Reading and appending preprocessed_data_13172.parquet
# Reading and appending preprocessed_data_13173.parquet
# Reading and appending preprocessed_data_13174.parquet
# Reading and appending preprocessed_data_13175.parquet
# Reading and appending preprocessed_data_13176.parquet
# Reading and appending preprocessed_data_13177.parquet
# Reading and appending preprocessed_data_13178.parquet
# Reading and appending preprocessed_data_13179.parquet
# Reading and appending preprocessed_data_13180.parquet
# Reading and appending preprocessed_data_13181.parquet
# Reading and appending preprocessed_data_13182.parquet
# Reading and appending preprocessed_data_13183.parquet
# Reading and appending preprocessed_data_13184.parquet
# Reading and appending preprocessed_data_13185.parquet
# Reading and appending preprocessed_data_13186.parquet
# Reading and appending preprocessed_data_13187.parquet
# Reading and appending preprocessed_data_13188.parquet
# Reading and appending preprocessed_data_13189.parquet
# Reading and appending preprocessed_data_13190.parquet
# Reading and appending preprocessed_data_13191.parquet
# Reading and appending preprocessed_data_13192.parquet
# Reading and appending preprocessed_data_13193.parquet
# Reading and appending preprocessed_data_13194.parquet
# Reading and appending preprocessed_data_13195.parquet
# Reading and appending preprocessed_data_13196.parquet
# Reading and appending preprocessed_data_13197.parquet
# Reading and appending preprocessed_data_13198.parquet
# Reading and appending preprocessed_data_13199.parquet
# Reading and appending preprocessed_data_13200.parquet
# Reading and appending preprocessed_data_13201.parquet
# Reading and appending preprocessed_data_13202.parquet
# Reading and appending preprocessed_data_13203.parquet
# Reading and appending preprocessed_data_13204.parquet
# Reading and appending preprocessed_data_13205.parquet
# Reading and appending preprocessed_data_13206.parquet
# Reading and appending preprocessed_data_13207.parquet
# Reading and appending preprocessed_data_13208.parquet
# Reading and appending preprocessed_data_13209.parquet
# Reading and appending preprocessed_data_13210.parquet
# Reading and appending preprocessed_data_13211.parquet
# Reading and appending preprocessed_data_13212.parquet
# Reading and appending preprocessed_data_13213.parquet
# Reading and appending preprocessed_data_13214.parquet
# Reading and appending preprocessed_data_13215.parquet
# Reading and appending preprocessed_data_13216.parquet
# Reading and appending preprocessed_data_13217.parquet
# Reading and appending preprocessed_data_13218.parquet
# Reading and appending preprocessed_data_13219.parquet
# Reading and appending preprocessed_data_13220.parquet
# Reading and appending preprocessed_data_13221.parquet
# Reading and appending preprocessed_data_13222.parquet
# Reading and appending preprocessed_data_13223.parquet
# Reading and appending preprocessed_data_13224.parquet
# Reading and appending preprocessed_data_13225.parquet
# Reading and appending preprocessed_data_13226.parquet
# Reading and appending preprocessed_data_13227.parquet
# Reading and appending preprocessed_data_13228.parquet
# Reading and appending preprocessed_data_13229.parquet
# Reading and appending preprocessed_data_13230.parquet
# Reading and appending preprocessed_data_13231.parquet
# Reading and appending preprocessed_data_13232.parquet
# Reading and appending preprocessed_data_13233.parquet
# Reading and appending preprocessed_data_13234.parquet
# Reading and appending preprocessed_data_13235.parquet
# Reading and appending preprocessed_data_13236.parquet
# Reading and appending preprocessed_data_13237.parquet
# Reading and appending preprocessed_data_13238.parquet
# Reading and appending preprocessed_data_13239.parquet
# Reading and appending preprocessed_data_13240.parquet
# Reading and appending preprocessed_data_13241.parquet
# Reading and appending preprocessed_data_13242.parquet
# Reading and appending preprocessed_data_13243.parquet
# Reading and appending preprocessed_data_13244.parquet
# Reading and appending preprocessed_data_13245.parquet
# Reading and appending preprocessed_data_13246.parquet
# Reading and appending preprocessed_data_13247.parquet
# Reading and appending preprocessed_data_13248.parquet
# Reading and appending preprocessed_data_13249.parquet
# Reading and appending preprocessed_data_13250.parquet
# Reading and appending preprocessed_data_13251.parquet
# Reading and appending preprocessed_data_13252.parquet
# Reading and appending preprocessed_data_13253.parquet
# Reading and appending preprocessed_data_13254.parquet
# Reading and appending preprocessed_data_13255.parquet
# Reading and appending preprocessed_data_13256.parquet
# Reading and appending preprocessed_data_13257.parquet
# Reading and appending preprocessed_data_13258.parquet
# Reading and appending preprocessed_data_13259.parquet
# Reading and appending preprocessed_data_13260.parquet
# Reading and appending preprocessed_data_13261.parquet
# Reading and appending preprocessed_data_13262.parquet
# Reading and appending preprocessed_data_13263.parquet
# Reading and appending preprocessed_data_13264.parquet
# Reading and appending preprocessed_data_13265.parquet
# Reading and appending preprocessed_data_13266.parquet
# Reading and appending preprocessed_data_13267.parquet
# Reading and appending preprocessed_data_13268.parquet
# Reading and appending preprocessed_data_13269.parquet
# Reading and appending preprocessed_data_13270.parquet
# Reading and appending preprocessed_data_13271.parquet
# Reading and appending preprocessed_data_13272.parquet
# Reading and appending preprocessed_data_13273.parquet
# Reading and appending preprocessed_data_13274.parquet
# Reading and appending preprocessed_data_13275.parquet
# Reading and appending preprocessed_data_13276.parquet
# Reading and appending preprocessed_data_13277.parquet
# Reading and appending preprocessed_data_13278.parquet
# Reading and appending preprocessed_data_13279.parquet
# Reading and appending preprocessed_data_13280.parquet
# Reading and appending preprocessed_data_13281.parquet
# Reading and appending preprocessed_data_13282.parquet
# Reading and appending preprocessed_data_13283.parquet
# Reading and appending preprocessed_data_13284.parquet
# Reading and appending preprocessed_data_13285.parquet
# Skipping preprocessed_data_13286.parquet as it does not exist
# Skipping preprocessed_data_13287.parquet as it does not exist
# Skipping preprocessed_data_13288.parquet as it does not exist
# Skipping preprocessed_data_13289.parquet as it does not exist
# Skipping preprocessed_data_13290.parquet as it does not exist
# Skipping preprocessed_data_13291.parquet as it does not exist
# Skipping preprocessed_data_13292.parquet as it does not exist
# Skipping preprocessed_data_13293.parquet as it does not exist
# Skipping preprocessed_data_13294.parquet as it does not exist
# Skipping preprocessed_data_13295.parquet as it does not exist
# Skipping preprocessed_data_13296.parquet as it does not exist
# Reading and appending preprocessed_data_13297.parquet
# Skipping preprocessed_data_13298.parquet as it does not exist
# Skipping preprocessed_data_13299.parquet as it does not exist
# Skipping preprocessed_data_13300.parquet as it does not exist
# Skipping preprocessed_data_13301.parquet as it does not exist
# Skipping preprocessed_data_13302.parquet as it does not exist
# Skipping preprocessed_data_13303.parquet as it does not exist
# Skipping preprocessed_data_13304.parquet as it does not exist
# Skipping preprocessed_data_13305.parquet as it does not exist
# Skipping preprocessed_data_13306.parquet as it does not exist
# Skipping preprocessed_data_13307.parquet as it does not exist
# Skipping preprocessed_data_13308.parquet as it does not exist
# Reading and appending preprocessed_data_13309.parquet
# Skipping preprocessed_data_13310.parquet as it does not exist
# Skipping preprocessed_data_13311.parquet as it does not exist
# Skipping preprocessed_data_13312.parquet as it does not exist
# Skipping preprocessed_data_13313.parquet as it does not exist
# Skipping preprocessed_data_13314.parquet as it does not exist
# Skipping preprocessed_data_13315.parquet as it does not exist
# Skipping preprocessed_data_13316.parquet as it does not exist
# Skipping preprocessed_data_13317.parquet as it does not exist
# Skipping preprocessed_data_13318.parquet as it does not exist
# Skipping preprocessed_data_13319.parquet as it does not exist
# Skipping preprocessed_data_13320.parquet as it does not exist
# Skipping preprocessed_data_13321.parquet as it does not exist
# Skipping preprocessed_data_13322.parquet as it does not exist
# Skipping preprocessed_data_13323.parquet as it does not exist
# Reading and appending preprocessed_data_13324.parquet
# Skipping preprocessed_data_13325.parquet as it does not exist
# Skipping preprocessed_data_13326.parquet as it does not exist
# Skipping preprocessed_data_13327.parquet as it does not exist
# Skipping preprocessed_data_13328.parquet as it does not exist
# Skipping preprocessed_data_13329.parquet as it does not exist
# Skipping preprocessed_data_13330.parquet as it does not exist
# Skipping preprocessed_data_13331.parquet as it does not exist
# Skipping preprocessed_data_13332.parquet as it does not exist
# Skipping preprocessed_data_13333.parquet as it does not exist
# Skipping preprocessed_data_13334.parquet as it does not exist
# Skipping preprocessed_data_13335.parquet as it does not exist
# Skipping preprocessed_data_13336.parquet as it does not exist
# Skipping preprocessed_data_13337.parquet as it does not exist
# Skipping preprocessed_data_13338.parquet as it does not exist
# Reading and appending preprocessed_data_13339.parquet
# Skipping preprocessed_data_13340.parquet as it does not exist
# Skipping preprocessed_data_13341.parquet as it does not exist
# Skipping preprocessed_data_13342.parquet as it does not exist
# Skipping preprocessed_data_13343.parquet as it does not exist
# Skipping preprocessed_data_13344.parquet as it does not exist
# Skipping preprocessed_data_13345.parquet as it does not exist
# Skipping preprocessed_data_13346.parquet as it does not exist
# Skipping preprocessed_data_13347.parquet as it does not exist
# Skipping preprocessed_data_13348.parquet as it does not exist
# Skipping preprocessed_data_13349.parquet as it does not exist
# Skipping preprocessed_data_13350.parquet as it does not exist
# Skipping preprocessed_data_13351.parquet as it does not exist
# Skipping preprocessed_data_13352.parquet as it does not exist
# Skipping preprocessed_data_13353.parquet as it does not exist
# Reading and appending preprocessed_data_13354.parquet
# Reading and appending preprocessed_data_13355.parquet
# Reading and appending preprocessed_data_13356.parquet
# Reading and appending preprocessed_data_13357.parquet
# Reading and appending preprocessed_data_13358.parquet
# Reading and appending preprocessed_data_13359.parquet
# Reading and appending preprocessed_data_13360.parquet
# Reading and appending preprocessed_data_13361.parquet
# Reading and appending preprocessed_data_13362.parquet
# Reading and appending preprocessed_data_13363.parquet
# Reading and appending preprocessed_data_13364.parquet
# Reading and appending preprocessed_data_13365.parquet
# Reading and appending preprocessed_data_13366.parquet
# Reading and appending preprocessed_data_13367.parquet
# Reading and appending preprocessed_data_13368.parquet
# Reading and appending preprocessed_data_13369.parquet
# Reading and appending preprocessed_data_13370.parquet
# Reading and appending preprocessed_data_13371.parquet
# Reading and appending preprocessed_data_13372.parquet
# Reading and appending preprocessed_data_13373.parquet
# Reading and appending preprocessed_data_13374.parquet
# Reading and appending preprocessed_data_13375.parquet
# Reading and appending preprocessed_data_13376.parquet
# Reading and appending preprocessed_data_13377.parquet
# Reading and appending preprocessed_data_13378.parquet
# Reading and appending preprocessed_data_13379.parquet
# Reading and appending preprocessed_data_13380.parquet
# Reading and appending preprocessed_data_13381.parquet
# Reading and appending preprocessed_data_13382.parquet
# Reading and appending preprocessed_data_13383.parquet
# Reading and appending preprocessed_data_13384.parquet
# Reading and appending preprocessed_data_13385.parquet
# Reading and appending preprocessed_data_13386.parquet
# Reading and appending preprocessed_data_13387.parquet
# Reading and appending preprocessed_data_13388.parquet
# Reading and appending preprocessed_data_13389.parquet
# Reading and appending preprocessed_data_13390.parquet
# Reading and appending preprocessed_data_13391.parquet
# Reading and appending preprocessed_data_13392.parquet
# Reading and appending preprocessed_data_13393.parquet
# Reading and appending preprocessed_data_13394.parquet
# Reading and appending preprocessed_data_13395.parquet
# Reading and appending preprocessed_data_13396.parquet
# Reading and appending preprocessed_data_13397.parquet
# Reading and appending preprocessed_data_13398.parquet
# Reading and appending preprocessed_data_13399.parquet
# Reading and appending preprocessed_data_13400.parquet
# Reading and appending preprocessed_data_13401.parquet
# Reading and appending preprocessed_data_13402.parquet
# Reading and appending preprocessed_data_13403.parquet
# Reading and appending preprocessed_data_13404.parquet
# Reading and appending preprocessed_data_13405.parquet
# Reading and appending preprocessed_data_13406.parquet
# Reading and appending preprocessed_data_13407.parquet
# Reading and appending preprocessed_data_13408.parquet
# Reading and appending preprocessed_data_13409.parquet
# Reading and appending preprocessed_data_13410.parquet
# Reading and appending preprocessed_data_13411.parquet
# Reading and appending preprocessed_data_13412.parquet
# Reading and appending preprocessed_data_13413.parquet
# Reading and appending preprocessed_data_13414.parquet
# Reading and appending preprocessed_data_13415.parquet
# Reading and appending preprocessed_data_13416.parquet
# Reading and appending preprocessed_data_13417.parquet
# Reading and appending preprocessed_data_13418.parquet
# Reading and appending preprocessed_data_13419.parquet
# Reading and appending preprocessed_data_13420.parquet
# Reading and appending preprocessed_data_13421.parquet
# Reading and appending preprocessed_data_13422.parquet
# Reading and appending preprocessed_data_13423.parquet
# Reading and appending preprocessed_data_13424.parquet
# Reading and appending preprocessed_data_13425.parquet
# Reading and appending preprocessed_data_13426.parquet
# Reading and appending preprocessed_data_13427.parquet
# Reading and appending preprocessed_data_13428.parquet
# Reading and appending preprocessed_data_13429.parquet
# Reading and appending preprocessed_data_13430.parquet
# Reading and appending preprocessed_data_13431.parquet
# Reading and appending preprocessed_data_13432.parquet
# Reading and appending preprocessed_data_13433.parquet
# Reading and appending preprocessed_data_13434.parquet
# Reading and appending preprocessed_data_13435.parquet
# Reading and appending preprocessed_data_13436.parquet
# Reading and appending preprocessed_data_13437.parquet
# Reading and appending preprocessed_data_13438.parquet
# Reading and appending preprocessed_data_13439.parquet
# Reading and appending preprocessed_data_13440.parquet
# Reading and appending preprocessed_data_13441.parquet
# Reading and appending preprocessed_data_13442.parquet
# Reading and appending preprocessed_data_13443.parquet
# Reading and appending preprocessed_data_13444.parquet
# Reading and appending preprocessed_data_13445.parquet
# Reading and appending preprocessed_data_13446.parquet
# Reading and appending preprocessed_data_13447.parquet
# Reading and appending preprocessed_data_13448.parquet
# Reading and appending preprocessed_data_13449.parquet
# Reading and appending preprocessed_data_13450.parquet
# Reading and appending preprocessed_data_13451.parquet
# Reading and appending preprocessed_data_13452.parquet
# Reading and appending preprocessed_data_13453.parquet
# Reading and appending preprocessed_data_13454.parquet
# Reading and appending preprocessed_data_13455.parquet
# Reading and appending preprocessed_data_13456.parquet
# Reading and appending preprocessed_data_13457.parquet
# Reading and appending preprocessed_data_13458.parquet
# Reading and appending preprocessed_data_13459.parquet
# Reading and appending preprocessed_data_13460.parquet
# Reading and appending preprocessed_data_13461.parquet
# Reading and appending preprocessed_data_13462.parquet
# Reading and appending preprocessed_data_13463.parquet
# Reading and appending preprocessed_data_13464.parquet
# Reading and appending preprocessed_data_13465.parquet
# Reading and appending preprocessed_data_13466.parquet
# Reading and appending preprocessed_data_13467.parquet
# Reading and appending preprocessed_data_13468.parquet
# Reading and appending preprocessed_data_13469.parquet
# Reading and appending preprocessed_data_13470.parquet
# Reading and appending preprocessed_data_13471.parquet
# Reading and appending preprocessed_data_13472.parquet
# Reading and appending preprocessed_data_13473.parquet
# Reading and appending preprocessed_data_13474.parquet
# Reading and appending preprocessed_data_13475.parquet
# Reading and appending preprocessed_data_13476.parquet
# Reading and appending preprocessed_data_13477.parquet
# Reading and appending preprocessed_data_13478.parquet
# Reading and appending preprocessed_data_13479.parquet
# Reading and appending preprocessed_data_13480.parquet
# Reading and appending preprocessed_data_13481.parquet
# Reading and appending preprocessed_data_13482.parquet
# Reading and appending preprocessed_data_13483.parquet
# Reading and appending preprocessed_data_13484.parquet
# Reading and appending preprocessed_data_13485.parquet
# Reading and appending preprocessed_data_13486.parquet
# Reading and appending preprocessed_data_13487.parquet
# Reading and appending preprocessed_data_13488.parquet
# Reading and appending preprocessed_data_13489.parquet
# Reading and appending preprocessed_data_13490.parquet
# Reading and appending preprocessed_data_13491.parquet
# Reading and appending preprocessed_data_13492.parquet
# Reading and appending preprocessed_data_13493.parquet
# Reading and appending preprocessed_data_13494.parquet
# Reading and appending preprocessed_data_13495.parquet
# Reading and appending preprocessed_data_13496.parquet
# Reading and appending preprocessed_data_13497.parquet
# Reading and appending preprocessed_data_13498.parquet
# Reading and appending preprocessed_data_13499.parquet
# Reading and appending preprocessed_data_13500.parquet
# Reading and appending preprocessed_data_13501.parquet
# Reading and appending preprocessed_data_13502.parquet
# Reading and appending preprocessed_data_13503.parquet
# Reading and appending preprocessed_data_13504.parquet
# Reading and appending preprocessed_data_13505.parquet
# Reading and appending preprocessed_data_13506.parquet
# Reading and appending preprocessed_data_13507.parquet
# Reading and appending preprocessed_data_13508.parquet
# Reading and appending preprocessed_data_13509.parquet
# Reading and appending preprocessed_data_13510.parquet
# Reading and appending preprocessed_data_13511.parquet
# Reading and appending preprocessed_data_13512.parquet
# Reading and appending preprocessed_data_13513.parquet
# Reading and appending preprocessed_data_13514.parquet
# Reading and appending preprocessed_data_13515.parquet
# Reading and appending preprocessed_data_13516.parquet
# Reading and appending preprocessed_data_13517.parquet
# Reading and appending preprocessed_data_13518.parquet
# Reading and appending preprocessed_data_13519.parquet
# Reading and appending preprocessed_data_13520.parquet
# Reading and appending preprocessed_data_13521.parquet
# Reading and appending preprocessed_data_13522.parquet
# Reading and appending preprocessed_data_13523.parquet
# Reading and appending preprocessed_data_13524.parquet
# Reading and appending preprocessed_data_13525.parquet
# Reading and appending preprocessed_data_13526.parquet
# Reading and appending preprocessed_data_13527.parquet
# Reading and appending preprocessed_data_13528.parquet
# Reading and appending preprocessed_data_13529.parquet
# Reading and appending preprocessed_data_13530.parquet
# Reading and appending preprocessed_data_13531.parquet
# Reading and appending preprocessed_data_13532.parquet
# Reading and appending preprocessed_data_13533.parquet
# Reading and appending preprocessed_data_13534.parquet
# Reading and appending preprocessed_data_13535.parquet
# Reading and appending preprocessed_data_13536.parquet
# Reading and appending preprocessed_data_13537.parquet
# Reading and appending preprocessed_data_13538.parquet
# Reading and appending preprocessed_data_13539.parquet
# Reading and appending preprocessed_data_13540.parquet
# Reading and appending preprocessed_data_13541.parquet
# Reading and appending preprocessed_data_13542.parquet
# Reading and appending preprocessed_data_13543.parquet
# Reading and appending preprocessed_data_13544.parquet
# Reading and appending preprocessed_data_13545.parquet
# Reading and appending preprocessed_data_13546.parquet
# Reading and appending preprocessed_data_13547.parquet
# Reading and appending preprocessed_data_13548.parquet
# Reading and appending preprocessed_data_13549.parquet
# Reading and appending preprocessed_data_13550.parquet
# Reading and appending preprocessed_data_13551.parquet
# Reading and appending preprocessed_data_13552.parquet
# Reading and appending preprocessed_data_13553.parquet
# Reading and appending preprocessed_data_13554.parquet
# Reading and appending preprocessed_data_13555.parquet
# Reading and appending preprocessed_data_13556.parquet
# Reading and appending preprocessed_data_13557.parquet
# Reading and appending preprocessed_data_13558.parquet
# Reading and appending preprocessed_data_13559.parquet
# Reading and appending preprocessed_data_13560.parquet
# Reading and appending preprocessed_data_13561.parquet
# Reading and appending preprocessed_data_13562.parquet
# Reading and appending preprocessed_data_13563.parquet
# Reading and appending preprocessed_data_13564.parquet
# Reading and appending preprocessed_data_13565.parquet
# Reading and appending preprocessed_data_13566.parquet
# Reading and appending preprocessed_data_13567.parquet
# Reading and appending preprocessed_data_13568.parquet
# Reading and appending preprocessed_data_13569.parquet
# Reading and appending preprocessed_data_13570.parquet
# Reading and appending preprocessed_data_13571.parquet
# Reading and appending preprocessed_data_13572.parquet
# Reading and appending preprocessed_data_13573.parquet
# Reading and appending preprocessed_data_13574.parquet
# Reading and appending preprocessed_data_13575.parquet
# Reading and appending preprocessed_data_13576.parquet
# Reading and appending preprocessed_data_13577.parquet
# Reading and appending preprocessed_data_13578.parquet
# Reading and appending preprocessed_data_13579.parquet
# Reading and appending preprocessed_data_13580.parquet
# Reading and appending preprocessed_data_13581.parquet
# Reading and appending preprocessed_data_13582.parquet
# Reading and appending preprocessed_data_13583.parquet
# Reading and appending preprocessed_data_13584.parquet
# Reading and appending preprocessed_data_13585.parquet
# Reading and appending preprocessed_data_13586.parquet
# Reading and appending preprocessed_data_13587.parquet
# Reading and appending preprocessed_data_13588.parquet
# Reading and appending preprocessed_data_13589.parquet
# Reading and appending preprocessed_data_13590.parquet
# Reading and appending preprocessed_data_13591.parquet
# Reading and appending preprocessed_data_13592.parquet
# Reading and appending preprocessed_data_13593.parquet
# Reading and appending preprocessed_data_13594.parquet
# Reading and appending preprocessed_data_13595.parquet
# Reading and appending preprocessed_data_13596.parquet
# Reading and appending preprocessed_data_13597.parquet
# Reading and appending preprocessed_data_13598.parquet
# Reading and appending preprocessed_data_13599.parquet
# Reading and appending preprocessed_data_13600.parquet
# Reading and appending preprocessed_data_13601.parquet
# Reading and appending preprocessed_data_13602.parquet
# Reading and appending preprocessed_data_13603.parquet
# Reading and appending preprocessed_data_13604.parquet
# Reading and appending preprocessed_data_13605.parquet
# Reading and appending preprocessed_data_13606.parquet
# Reading and appending preprocessed_data_13607.parquet
# Reading and appending preprocessed_data_13608.parquet
# Reading and appending preprocessed_data_13609.parquet
# Reading and appending preprocessed_data_13610.parquet
# Reading and appending preprocessed_data_13611.parquet
# Reading and appending preprocessed_data_13612.parquet
# Reading and appending preprocessed_data_13613.parquet
# Reading and appending preprocessed_data_13614.parquet
# Reading and appending preprocessed_data_13615.parquet
# Reading and appending preprocessed_data_13616.parquet
# Reading and appending preprocessed_data_13617.parquet
# Reading and appending preprocessed_data_13618.parquet
# Reading and appending preprocessed_data_13619.parquet
# Reading and appending preprocessed_data_13620.parquet
# Reading and appending preprocessed_data_13621.parquet
# Reading and appending preprocessed_data_13622.parquet
# Reading and appending preprocessed_data_13623.parquet
# Reading and appending preprocessed_data_13624.parquet
# Reading and appending preprocessed_data_13625.parquet
# Reading and appending preprocessed_data_13626.parquet
# Reading and appending preprocessed_data_13627.parquet
# Reading and appending preprocessed_data_13628.parquet
# Reading and appending preprocessed_data_13629.parquet
# Reading and appending preprocessed_data_13630.parquet
# Reading and appending preprocessed_data_13631.parquet
# Reading and appending preprocessed_data_13632.parquet
# Reading and appending preprocessed_data_13633.parquet
# Reading and appending preprocessed_data_13634.parquet
# Reading and appending preprocessed_data_13635.parquet
# Reading and appending preprocessed_data_13636.parquet
# Reading and appending preprocessed_data_13637.parquet
# Reading and appending preprocessed_data_13638.parquet
# Reading and appending preprocessed_data_13639.parquet
# Reading and appending preprocessed_data_13640.parquet
# Reading and appending preprocessed_data_13641.parquet
# Reading and appending preprocessed_data_13642.parquet
# Reading and appending preprocessed_data_13643.parquet
# Reading and appending preprocessed_data_13644.parquet
# Reading and appending preprocessed_data_13645.parquet
# Reading and appending preprocessed_data_13646.parquet
# Reading and appending preprocessed_data_13647.parquet
# Reading and appending preprocessed_data_13648.parquet
# Reading and appending preprocessed_data_13649.parquet
# Reading and appending preprocessed_data_13650.parquet
# Reading and appending preprocessed_data_13651.parquet
# Reading and appending preprocessed_data_13652.parquet
# Reading and appending preprocessed_data_13653.parquet
# Reading and appending preprocessed_data_13654.parquet
# Reading and appending preprocessed_data_13655.parquet
# Reading and appending preprocessed_data_13656.parquet
# Reading and appending preprocessed_data_13657.parquet
# Reading and appending preprocessed_data_13658.parquet
# Reading and appending preprocessed_data_13659.parquet
# Reading and appending preprocessed_data_13660.parquet
# Reading and appending preprocessed_data_13661.parquet
# Reading and appending preprocessed_data_13662.parquet
# Reading and appending preprocessed_data_13663.parquet
# Reading and appending preprocessed_data_13664.parquet
# Reading and appending preprocessed_data_13665.parquet
# Reading and appending preprocessed_data_13666.parquet
# Reading and appending preprocessed_data_13667.parquet
# Reading and appending preprocessed_data_13668.parquet
# Reading and appending preprocessed_data_13669.parquet
# Reading and appending preprocessed_data_13670.parquet
# Reading and appending preprocessed_data_13671.parquet
# Reading and appending preprocessed_data_13672.parquet
# Reading and appending preprocessed_data_13673.parquet
# Reading and appending preprocessed_data_13674.parquet
# Reading and appending preprocessed_data_13675.parquet
# Reading and appending preprocessed_data_13676.parquet
# Reading and appending preprocessed_data_13677.parquet
# Reading and appending preprocessed_data_13678.parquet
# Reading and appending preprocessed_data_13679.parquet
# Reading and appending preprocessed_data_13680.parquet
# Reading and appending preprocessed_data_13681.parquet
# Reading and appending preprocessed_data_13682.parquet
# Reading and appending preprocessed_data_13683.parquet
# Reading and appending preprocessed_data_13684.parquet
# Reading and appending preprocessed_data_13685.parquet
# Reading and appending preprocessed_data_13686.parquet
# Reading and appending preprocessed_data_13687.parquet
# Reading and appending preprocessed_data_13688.parquet
# Reading and appending preprocessed_data_13689.parquet
# Reading and appending preprocessed_data_13690.parquet
# Reading and appending preprocessed_data_13691.parquet
# Reading and appending preprocessed_data_13692.parquet
# Reading and appending preprocessed_data_13693.parquet
# Reading and appending preprocessed_data_13694.parquet
# Reading and appending preprocessed_data_13695.parquet
# Reading and appending preprocessed_data_13696.parquet
# Reading and appending preprocessed_data_13697.parquet
# Reading and appending preprocessed_data_13698.parquet
# Reading and appending preprocessed_data_13699.parquet
# Reading and appending preprocessed_data_13700.parquet
# Reading and appending preprocessed_data_13701.parquet
# Reading and appending preprocessed_data_13702.parquet
# Reading and appending preprocessed_data_13703.parquet
# Reading and appending preprocessed_data_13704.parquet
# Reading and appending preprocessed_data_13705.parquet
# Reading and appending preprocessed_data_13706.parquet
# Reading and appending preprocessed_data_13707.parquet
# Reading and appending preprocessed_data_13708.parquet
# Reading and appending preprocessed_data_13709.parquet
# Reading and appending preprocessed_data_13710.parquet
# Reading and appending preprocessed_data_13711.parquet
# Reading and appending preprocessed_data_13712.parquet
# Reading and appending preprocessed_data_13713.parquet
# Reading and appending preprocessed_data_13714.parquet
# Reading and appending preprocessed_data_13715.parquet
# Reading and appending preprocessed_data_13716.parquet
# Reading and appending preprocessed_data_13717.parquet
# Reading and appending preprocessed_data_13718.parquet
# Reading and appending preprocessed_data_13719.parquet
# Reading and appending preprocessed_data_13720.parquet
# Reading and appending preprocessed_data_13721.parquet
# Reading and appending preprocessed_data_13722.parquet
# Reading and appending preprocessed_data_13723.parquet
# Reading and appending preprocessed_data_13724.parquet
# Reading and appending preprocessed_data_13725.parquet
# Reading and appending preprocessed_data_13726.parquet
# Reading and appending preprocessed_data_13727.parquet
# Reading and appending preprocessed_data_13728.parquet
# Reading and appending preprocessed_data_13729.parquet
# Reading and appending preprocessed_data_13730.parquet
# Reading and appending preprocessed_data_13731.parquet
# Reading and appending preprocessed_data_13732.parquet
# Reading and appending preprocessed_data_13733.parquet
# Reading and appending preprocessed_data_13734.parquet
# Reading and appending preprocessed_data_13735.parquet
# Reading and appending preprocessed_data_13736.parquet
# Reading and appending preprocessed_data_13737.parquet
# Reading and appending preprocessed_data_13738.parquet
# Reading and appending preprocessed_data_13739.parquet
# Reading and appending preprocessed_data_13740.parquet
# Reading and appending preprocessed_data_13741.parquet
# Reading and appending preprocessed_data_13742.parquet
# Reading and appending preprocessed_data_13743.parquet
# Reading and appending preprocessed_data_13744.parquet
# Skipping preprocessed_data_13745.parquet as it does not exist
# Skipping preprocessed_data_13746.parquet as it does not exist
# Skipping preprocessed_data_13747.parquet as it does not exist
# Skipping preprocessed_data_13748.parquet as it does not exist
# Skipping preprocessed_data_13749.parquet as it does not exist
# Skipping preprocessed_data_13750.parquet as it does not exist
# Skipping preprocessed_data_13751.parquet as it does not exist
# Skipping preprocessed_data_13752.parquet as it does not exist
# Skipping preprocessed_data_13753.parquet as it does not exist
# Skipping preprocessed_data_13754.parquet as it does not exist
# Skipping preprocessed_data_13755.parquet as it does not exist
# Skipping preprocessed_data_13756.parquet as it does not exist
# Skipping preprocessed_data_13757.parquet as it does not exist
# Skipping preprocessed_data_13758.parquet as it does not exist
# Reading and appending preprocessed_data_13759.parquet
# Skipping preprocessed_data_13760.parquet as it does not exist
# Skipping preprocessed_data_13761.parquet as it does not exist
# Skipping preprocessed_data_13762.parquet as it does not exist
# Skipping preprocessed_data_13763.parquet as it does not exist
# Skipping preprocessed_data_13764.parquet as it does not exist
# Skipping preprocessed_data_13765.parquet as it does not exist
# Skipping preprocessed_data_13766.parquet as it does not exist
# Skipping preprocessed_data_13767.parquet as it does not exist
# Skipping preprocessed_data_13768.parquet as it does not exist
# Skipping preprocessed_data_13769.parquet as it does not exist
# Skipping preprocessed_data_13770.parquet as it does not exist
# Skipping preprocessed_data_13771.parquet as it does not exist
# Skipping preprocessed_data_13772.parquet as it does not exist
# Skipping preprocessed_data_13773.parquet as it does not exist
# Reading and appending preprocessed_data_13774.parquet
# Reading and appending preprocessed_data_13775.parquet
# Reading and appending preprocessed_data_13776.parquet
# Reading and appending preprocessed_data_13777.parquet
# Reading and appending preprocessed_data_13778.parquet
# Reading and appending preprocessed_data_13779.parquet
# Reading and appending preprocessed_data_13780.parquet
# Reading and appending preprocessed_data_13781.parquet
# Reading and appending preprocessed_data_13782.parquet
# Reading and appending preprocessed_data_13783.parquet
# Reading and appending preprocessed_data_13784.parquet
# Reading and appending preprocessed_data_13785.parquet
# Reading and appending preprocessed_data_13786.parquet
# Reading and appending preprocessed_data_13787.parquet
# Reading and appending preprocessed_data_13788.parquet
# Reading and appending preprocessed_data_13789.parquet
# Reading and appending preprocessed_data_13790.parquet
# Reading and appending preprocessed_data_13791.parquet
# Reading and appending preprocessed_data_13792.parquet
# Reading and appending preprocessed_data_13793.parquet
# Reading and appending preprocessed_data_13794.parquet
# Reading and appending preprocessed_data_13795.parquet
# Reading and appending preprocessed_data_13796.parquet
# Reading and appending preprocessed_data_13797.parquet
# Reading and appending preprocessed_data_13798.parquet
# Reading and appending preprocessed_data_13799.parquet
# Reading and appending preprocessed_data_13800.parquet
# Reading and appending preprocessed_data_13801.parquet
# Reading and appending preprocessed_data_13802.parquet
# Reading and appending preprocessed_data_13803.parquet
# Reading and appending preprocessed_data_13804.parquet
# Skipping preprocessed_data_13805.parquet as it does not exist
# Skipping preprocessed_data_13806.parquet as it does not exist
# Skipping preprocessed_data_13807.parquet as it does not exist
# Skipping preprocessed_data_13808.parquet as it does not exist
# Skipping preprocessed_data_13809.parquet as it does not exist
# Skipping preprocessed_data_13810.parquet as it does not exist
# Skipping preprocessed_data_13811.parquet as it does not exist
# Skipping preprocessed_data_13812.parquet as it does not exist
# Skipping preprocessed_data_13813.parquet as it does not exist
# Skipping preprocessed_data_13814.parquet as it does not exist
# Skipping preprocessed_data_13815.parquet as it does not exist
# Skipping preprocessed_data_13816.parquet as it does not exist
# Skipping preprocessed_data_13817.parquet as it does not exist
# Skipping preprocessed_data_13818.parquet as it does not exist
# Reading and appending preprocessed_data_13819.parquet
# Skipping preprocessed_data_13820.parquet as it does not exist
# Skipping preprocessed_data_13821.parquet as it does not exist
# Skipping preprocessed_data_13822.parquet as it does not exist
# Skipping preprocessed_data_13823.parquet as it does not exist
# Skipping preprocessed_data_13824.parquet as it does not exist
# Skipping preprocessed_data_13825.parquet as it does not exist
# Skipping preprocessed_data_13826.parquet as it does not exist
# Skipping preprocessed_data_13827.parquet as it does not exist
# Skipping preprocessed_data_13828.parquet as it does not exist
# Skipping preprocessed_data_13829.parquet as it does not exist
# Skipping preprocessed_data_13830.parquet as it does not exist
# Skipping preprocessed_data_13831.parquet as it does not exist
# Skipping preprocessed_data_13832.parquet as it does not exist
# Skipping preprocessed_data_13833.parquet as it does not exist
# Reading and appending preprocessed_data_13834.parquet
# Skipping preprocessed_data_13835.parquet as it does not exist
# Skipping preprocessed_data_13836.parquet as it does not exist
# Skipping preprocessed_data_13837.parquet as it does not exist
# Skipping preprocessed_data_13838.parquet as it does not exist
# Skipping preprocessed_data_13839.parquet as it does not exist
# Skipping preprocessed_data_13840.parquet as it does not exist
# Skipping preprocessed_data_13841.parquet as it does not exist
# Skipping preprocessed_data_13842.parquet as it does not exist
# Skipping preprocessed_data_13843.parquet as it does not exist
# Skipping preprocessed_data_13844.parquet as it does not exist
# Skipping preprocessed_data_13845.parquet as it does not exist
# Skipping preprocessed_data_13846.parquet as it does not exist
# Skipping preprocessed_data_13847.parquet as it does not exist
# Skipping preprocessed_data_13848.parquet as it does not exist
# Reading and appending preprocessed_data_13849.parquet
# Skipping preprocessed_data_13850.parquet as it does not exist
# Skipping preprocessed_data_13851.parquet as it does not exist
# Skipping preprocessed_data_13852.parquet as it does not exist
# Skipping preprocessed_data_13853.parquet as it does not exist
# Skipping preprocessed_data_13854.parquet as it does not exist
# Skipping preprocessed_data_13855.parquet as it does not exist
# Skipping preprocessed_data_13856.parquet as it does not exist
# Skipping preprocessed_data_13857.parquet as it does not exist
# Skipping preprocessed_data_13858.parquet as it does not exist
# Skipping preprocessed_data_13859.parquet as it does not exist
# Skipping preprocessed_data_13860.parquet as it does not exist
# Skipping preprocessed_data_13861.parquet as it does not exist
# Skipping preprocessed_data_13862.parquet as it does not exist
# Skipping preprocessed_data_13863.parquet as it does not exist
# Reading and appending preprocessed_data_13864.parquet
# Reading and appending preprocessed_data_13865.parquet
# Reading and appending preprocessed_data_13866.parquet
# Reading and appending preprocessed_data_13867.parquet
# Reading and appending preprocessed_data_13868.parquet
# Reading and appending preprocessed_data_13869.parquet
# Reading and appending preprocessed_data_13870.parquet
# Reading and appending preprocessed_data_13871.parquet
# Reading and appending preprocessed_data_13872.parquet
# Reading and appending preprocessed_data_13873.parquet
# Reading and appending preprocessed_data_13874.parquet
# Reading and appending preprocessed_data_13875.parquet
# Reading and appending preprocessed_data_13876.parquet
# Reading and appending preprocessed_data_13877.parquet
# Reading and appending preprocessed_data_13878.parquet
# Reading and appending preprocessed_data_13879.parquet
# Reading and appending preprocessed_data_13880.parquet
# Reading and appending preprocessed_data_13881.parquet
# Reading and appending preprocessed_data_13882.parquet
# Reading and appending preprocessed_data_13883.parquet
# Reading and appending preprocessed_data_13884.parquet
# Reading and appending preprocessed_data_13885.parquet
# Reading and appending preprocessed_data_13886.parquet
# Reading and appending preprocessed_data_13887.parquet
# Reading and appending preprocessed_data_13888.parquet
# Reading and appending preprocessed_data_13889.parquet
# Reading and appending preprocessed_data_13890.parquet
# Reading and appending preprocessed_data_13891.parquet
# Reading and appending preprocessed_data_13892.parquet
# Reading and appending preprocessed_data_13893.parquet
# Reading and appending preprocessed_data_13894.parquet
# Reading and appending preprocessed_data_13895.parquet
# Reading and appending preprocessed_data_13896.parquet
# Reading and appending preprocessed_data_13897.parquet
# Reading and appending preprocessed_data_13898.parquet
# Reading and appending preprocessed_data_13899.parquet
# Reading and appending preprocessed_data_13900.parquet
# Reading and appending preprocessed_data_13901.parquet
# Skipping preprocessed_data_13902.parquet as it does not exist
# Skipping preprocessed_data_13903.parquet as it does not exist
# Skipping preprocessed_data_13904.parquet as it does not exist
# Skipping preprocessed_data_13905.parquet as it does not exist
# Skipping preprocessed_data_13906.parquet as it does not exist
# Skipping preprocessed_data_13907.parquet as it does not exist
# Reading and appending preprocessed_data_13908.parquet
# Reading and appending preprocessed_data_13909.parquet
# Reading and appending preprocessed_data_13910.parquet
# Reading and appending preprocessed_data_13911.parquet
# Reading and appending preprocessed_data_13912.parquet
# Reading and appending preprocessed_data_13913.parquet
# Reading and appending preprocessed_data_13914.parquet
# Reading and appending preprocessed_data_13915.parquet
# Reading and appending preprocessed_data_13916.parquet
# Reading and appending preprocessed_data_13917.parquet
# Reading and appending preprocessed_data_13918.parquet
# Reading and appending preprocessed_data_13919.parquet
# Reading and appending preprocessed_data_13920.parquet
# Reading and appending preprocessed_data_13921.parquet
# Reading and appending preprocessed_data_13922.parquet
# Reading and appending preprocessed_data_13923.parquet
# Reading and appending preprocessed_data_13924.parquet
# Reading and appending preprocessed_data_13925.parquet
# Reading and appending preprocessed_data_13926.parquet
# Reading and appending preprocessed_data_13927.parquet
# Reading and appending preprocessed_data_13928.parquet
# Reading and appending preprocessed_data_13929.parquet
# Reading and appending preprocessed_data_13930.parquet
# Reading and appending preprocessed_data_13931.parquet
# Reading and appending preprocessed_data_13932.parquet
# Reading and appending preprocessed_data_13933.parquet
# Reading and appending preprocessed_data_13934.parquet
# Reading and appending preprocessed_data_13935.parquet
# Reading and appending preprocessed_data_13936.parquet
# Reading and appending preprocessed_data_13937.parquet
# Reading and appending preprocessed_data_13938.parquet
# Reading and appending preprocessed_data_13939.parquet
# Reading and appending preprocessed_data_13940.parquet
# Reading and appending preprocessed_data_13941.parquet
# Reading and appending preprocessed_data_13942.parquet
# Reading and appending preprocessed_data_13943.parquet
# Reading and appending preprocessed_data_13944.parquet
# Reading and appending preprocessed_data_13945.parquet
# Reading and appending preprocessed_data_13946.parquet
# Reading and appending preprocessed_data_13947.parquet
# Reading and appending preprocessed_data_13948.parquet
# Reading and appending preprocessed_data_13949.parquet
# Reading and appending preprocessed_data_13950.parquet
# Reading and appending preprocessed_data_13951.parquet
# Reading and appending preprocessed_data_13952.parquet
# Reading and appending preprocessed_data_13953.parquet
# Reading and appending preprocessed_data_13954.parquet
# Reading and appending preprocessed_data_13955.parquet
# Reading and appending preprocessed_data_13956.parquet
# Reading and appending preprocessed_data_13957.parquet
# Reading and appending preprocessed_data_13958.parquet
# Reading and appending preprocessed_data_13959.parquet
# Reading and appending preprocessed_data_13960.parquet
# Reading and appending preprocessed_data_13961.parquet
# Reading and appending preprocessed_data_13962.parquet
# Reading and appending preprocessed_data_13963.parquet
# Reading and appending preprocessed_data_13964.parquet
# Reading and appending preprocessed_data_13965.parquet
# Reading and appending preprocessed_data_13966.parquet
# Reading and appending preprocessed_data_13967.parquet
# Reading and appending preprocessed_data_13968.parquet
# Reading and appending preprocessed_data_13969.parquet
# Reading and appending preprocessed_data_13970.parquet
# Reading and appending preprocessed_data_13971.parquet
# Reading and appending preprocessed_data_13972.parquet
# Reading and appending preprocessed_data_13973.parquet
# Reading and appending preprocessed_data_13974.parquet
# Reading and appending preprocessed_data_13975.parquet
# Reading and appending preprocessed_data_13976.parquet
# Reading and appending preprocessed_data_13977.parquet
# Reading and appending preprocessed_data_13978.parquet
# Reading and appending preprocessed_data_13979.parquet
# Reading and appending preprocessed_data_13980.parquet
# Reading and appending preprocessed_data_13981.parquet
# Reading and appending preprocessed_data_13982.parquet
# Reading and appending preprocessed_data_13983.parquet
# Reading and appending preprocessed_data_13984.parquet
# Reading and appending preprocessed_data_13985.parquet
# Reading and appending preprocessed_data_13986.parquet
# Reading and appending preprocessed_data_13987.parquet
# Reading and appending preprocessed_data_13988.parquet
# Reading and appending preprocessed_data_13989.parquet
# Reading and appending preprocessed_data_13990.parquet
# Reading and appending preprocessed_data_13991.parquet
# Reading and appending preprocessed_data_13992.parquet
# Reading and appending preprocessed_data_13993.parquet
# Reading and appending preprocessed_data_13994.parquet
# Reading and appending preprocessed_data_13995.parquet
# Reading and appending preprocessed_data_13996.parquet
# Reading and appending preprocessed_data_13997.parquet
# Reading and appending preprocessed_data_13998.parquet
# Reading and appending preprocessed_data_13999.parquet
# Reading and appending preprocessed_data_14000.parquet
# ...
# Reading and appending preprocessed_data_17855.parquet
# Reading and appending preprocessed_data_17856.parquet
# Reading and appending preprocessed_data_17857.parquet
# Reading and appending preprocessed_data_17858.parquet
# Reading and appending preprocessed_data_17859.parquet
# Reading and appending preprocessed_data_17860.parquet
# Reading and appending preprocessed_data_17861.parquet
# Reading and appending preprocessed_data_17862.parquet
# Reading and appending preprocessed_data_17863.parquet
# Reading and appending preprocessed_data_17864.parquet
# Reading and appending preprocessed_data_17865.parquet
# Reading and appending preprocessed_data_17866.parquet
# Reading and appending preprocessed_data_17867.parquet
# Reading and appending preprocessed_data_17868.parquet
# Reading and appending preprocessed_data_17869.parquet
# Reading and appending preprocessed_data_17870.parquet
# Reading and appending preprocessed_data_17871.parquet
# Reading and appending preprocessed_data_17872.parquet
# Reading and appending preprocessed_data_17873.parquet
# Reading and appending preprocessed_data_17874.parquet
# Reading and appending preprocessed_data_17875.parquet
# Reading and appending preprocessed_data_17876.parquet
# Reading and appending preprocessed_data_17877.parquet
# Reading and appending preprocessed_data_17878.parquet
# Reading and appending preprocessed_data_17879.parquet
# Reading and appending preprocessed_data_17880.parquet
# Reading and appending preprocessed_data_17881.parquet
# Reading and appending preprocessed_data_17882.parquet
# Reading and appending preprocessed_data_17883.parquet
# Reading and appending preprocessed_data_17884.parquet
# Reading and appending preprocessed_data_17885.parquet
# Reading and appending preprocessed_data_17886.parquet
# Reading and appending preprocessed_data_17887.parquet
# Reading and appending preprocessed_data_17888.parquet
# Reading and appending preprocessed_data_17889.parquet
# Reading and appending preprocessed_data_17890.parquet
# Reading and appending preprocessed_data_17891.parquet
# Reading and appending preprocessed_data_17892.parquet
# Reading and appending preprocessed_data_17893.parquet
# Reading and appending preprocessed_data_17894.parquet
# Reading and appending preprocessed_data_17895.parquet
# Reading and appending preprocessed_data_17896.parquet
# Reading and appending preprocessed_data_17897.parquet
# Reading and appending preprocessed_data_17898.parquet
# Reading and appending preprocessed_data_17899.parquet
# Reading and appending preprocessed_data_17900.parquet
# Reading and appending preprocessed_data_17901.parquet
# Reading and appending preprocessed_data_17902.parquet
# Reading and appending preprocessed_data_17903.parquet
# Reading and appending preprocessed_data_17904.parquet
# Reading and appending preprocessed_data_17905.parquet
# Reading and appending preprocessed_data_17906.parquet
# Reading and appending preprocessed_data_17907.parquet
# Reading and appending preprocessed_data_17908.parquet
# Reading and appending preprocessed_data_17909.parquet
# Reading and appending preprocessed_data_17910.parquet
# Reading and appending preprocessed_data_17911.parquet
# Reading and appending preprocessed_data_17912.parquet
# Reading and appending preprocessed_data_17913.parquet
# Reading and appending preprocessed_data_17914.parquet
# Reading and appending preprocessed_data_17915.parquet
# Reading and appending preprocessed_data_17916.parquet
# Reading and appending preprocessed_data_17917.parquet
# Reading and appending preprocessed_data_17918.parquet
# Reading and appending preprocessed_data_17919.parquet
# Reading and appending preprocessed_data_17920.parquet
# Reading and appending preprocessed_data_17921.parquet
# Reading and appending preprocessed_data_17922.parquet
# Reading and appending preprocessed_data_17923.parquet
# Reading and appending preprocessed_data_17924.parquet
# Reading and appending preprocessed_data_17925.parquet
# Reading and appending preprocessed_data_17926.parquet
# Reading and appending preprocessed_data_17927.parquet
# Reading and appending preprocessed_data_17928.parquet
# Reading and appending preprocessed_data_17929.parquet
# Reading and appending preprocessed_data_17930.parquet
# Reading and appending preprocessed_data_17931.parquet
# Reading and appending preprocessed_data_17932.parquet
# Reading and appending preprocessed_data_17933.parquet
# Reading and appending preprocessed_data_17934.parquet
# Reading and appending preprocessed_data_17935.parquet
# Reading and appending preprocessed_data_17936.parquet
# Reading and appending preprocessed_data_17937.parquet
# Reading and appending preprocessed_data_17938.parquet
# Reading and appending preprocessed_data_17939.parquet
# Reading and appending preprocessed_data_17940.parquet
# Reading and appending preprocessed_data_17941.parquet
# Reading and appending preprocessed_data_17942.parquet
# Reading and appending preprocessed_data_17943.parquet
# Reading and appending preprocessed_data_17944.parquet
# Reading and appending preprocessed_data_17945.parquet
# Reading and appending preprocessed_data_17946.parquet
# Reading and appending preprocessed_data_17947.parquet
# Reading and appending preprocessed_data_17948.parquet
# Reading and appending preprocessed_data_17949.parquet
# Reading and appending preprocessed_data_17950.parquet
# Reading and appending preprocessed_data_17951.parquet
# Reading and appending preprocessed_data_17952.parquet
# Reading and appending preprocessed_data_17953.parquet
# Reading and appending preprocessed_data_17954.parquet
# Reading and appending preprocessed_data_17955.parquet
# Reading and appending preprocessed_data_17956.parquet
# Reading and appending preprocessed_data_17957.parquet
# Reading and appending preprocessed_data_17958.parquet
# Reading and appending preprocessed_data_17959.parquet
# Reading and appending preprocessed_data_17960.parquet
# Reading and appending preprocessed_data_17961.parquet
# Reading and appending preprocessed_data_17962.parquet
# Reading and appending preprocessed_data_17963.parquet
# Reading and appending preprocessed_data_17964.parquet
# Reading and appending preprocessed_data_17965.parquet
# Reading and appending preprocessed_data_17966.parquet
# Reading and appending preprocessed_data_17967.parquet
# Reading and appending preprocessed_data_17968.parquet
# Reading and appending preprocessed_data_17969.parquet
# Reading and appending preprocessed_data_17970.parquet
# Reading and appending preprocessed_data_17971.parquet
# Reading and appending preprocessed_data_17972.parquet
# Reading and appending preprocessed_data_17973.parquet
# Reading and appending preprocessed_data_17974.parquet
# Reading and appending preprocessed_data_17975.parquet
# Reading and appending preprocessed_data_17976.parquet
# Reading and appending preprocessed_data_17977.parquet
# Reading and appending preprocessed_data_17978.parquet
# Reading and appending preprocessed_data_17979.parquet
# Reading and appending preprocessed_data_17980.parquet
# Reading and appending preprocessed_data_17981.parquet
# Reading and appending preprocessed_data_17982.parquet
# Reading and appending preprocessed_data_17983.parquet
# Reading and appending preprocessed_data_17984.parquet
# Reading and appending preprocessed_data_17985.parquet
# Reading and appending preprocessed_data_17986.parquet
# Reading and appending preprocessed_data_17987.parquet
# Reading and appending preprocessed_data_17988.parquet
# Reading and appending preprocessed_data_17989.parquet
# Reading and appending preprocessed_data_17990.parquet
# Reading and appending preprocessed_data_17991.parquet
# Reading and appending preprocessed_data_17992.parquet
# Reading and appending preprocessed_data_17993.parquet
# Reading and appending preprocessed_data_17994.parquet
# Reading and appending preprocessed_data_17995.parquet
# Reading and appending preprocessed_data_17996.parquet
# Reading and appending preprocessed_data_17997.parquet
# Reading and appending preprocessed_data_17998.parquet
# Reading and appending preprocessed_data_17999.parquet
# Reading and appending preprocessed_data_18000.parquet
# Reading and appending preprocessed_data_18001.parquet
# Reading and appending preprocessed_data_18002.parquet
# Reading and appending preprocessed_data_18003.parquet
# Reading and appending preprocessed_data_18004.parquet
# Reading and appending preprocessed_data_18005.parquet
# Reading and appending preprocessed_data_18006.parquet
# Reading and appending preprocessed_data_18007.parquet
# Reading and appending preprocessed_data_18008.parquet
# Reading and appending preprocessed_data_18009.parquet
# Reading and appending preprocessed_data_18010.parquet
# Reading and appending preprocessed_data_18011.parquet
# Reading and appending preprocessed_data_18012.parquet
# Reading and appending preprocessed_data_18013.parquet
# Reading and appending preprocessed_data_18014.parquet
# Reading and appending preprocessed_data_18015.parquet
# Reading and appending preprocessed_data_18016.parquet
# Reading and appending preprocessed_data_18017.parquet
# Reading and appending preprocessed_data_18018.parquet
# Skipping preprocessed_data_18019.parquet as it does not exist
# Skipping preprocessed_data_18020.parquet as it does not exist
# Skipping preprocessed_data_18021.parquet as it does not exist
# Skipping preprocessed_data_18022.parquet as it does not exist
# Skipping preprocessed_data_18023.parquet as it does not exist
# Skipping preprocessed_data_18024.parquet as it does not exist
# Skipping preprocessed_data_18025.parquet as it does not exist
# Skipping preprocessed_data_18026.parquet as it does not exist
# Skipping preprocessed_data_18027.parquet as it does not exist
# Skipping preprocessed_data_18028.parquet as it does not exist
# Skipping preprocessed_data_18029.parquet as it does not exist
# Skipping preprocessed_data_18030.parquet as it does not exist
# Skipping preprocessed_data_18031.parquet as it does not exist
# Skipping preprocessed_data_18032.parquet as it does not exist
# Reading and appending preprocessed_data_18033.parquet
# Skipping preprocessed_data_18034.parquet as it does not exist
# Skipping preprocessed_data_18035.parquet as it does not exist
# Skipping preprocessed_data_18036.parquet as it does not exist
# Skipping preprocessed_data_18037.parquet as it does not exist
# Skipping preprocessed_data_18038.parquet as it does not exist
# Skipping preprocessed_data_18039.parquet as it does not exist
# Skipping preprocessed_data_18040.parquet as it does not exist
# Skipping preprocessed_data_18041.parquet as it does not exist
# Skipping preprocessed_data_18042.parquet as it does not exist
# Skipping preprocessed_data_18043.parquet as it does not exist
# Skipping preprocessed_data_18044.parquet as it does not exist
# Skipping preprocessed_data_18045.parquet as it does not exist
# Skipping preprocessed_data_18046.parquet as it does not exist
# Skipping preprocessed_data_18047.parquet as it does not exist
# Skipping preprocessed_data_18048.parquet as it does not exist
# Reading and appending preprocessed_data_18049.parquet
# Skipping preprocessed_data_18050.parquet as it does not exist
# Skipping preprocessed_data_18051.parquet as it does not exist
# Skipping preprocessed_data_18052.parquet as it does not exist
# Skipping preprocessed_data_18053.parquet as it does not exist
# Skipping preprocessed_data_18054.parquet as it does not exist
# Skipping preprocessed_data_18055.parquet as it does not exist
# Skipping preprocessed_data_18056.parquet as it does not exist
# Skipping preprocessed_data_18057.parquet as it does not exist
# Skipping preprocessed_data_18058.parquet as it does not exist
# Skipping preprocessed_data_18059.parquet as it does not exist
# Skipping preprocessed_data_18060.parquet as it does not exist
# Skipping preprocessed_data_18061.parquet as it does not exist
# Skipping preprocessed_data_18062.parquet as it does not exist
# Reading and appending preprocessed_data_18063.parquet
# Skipping preprocessed_data_18064.parquet as it does not exist
# Skipping preprocessed_data_18065.parquet as it does not exist
# Skipping preprocessed_data_18066.parquet as it does not exist
# Skipping preprocessed_data_18067.parquet as it does not exist
# Skipping preprocessed_data_18068.parquet as it does not exist
# Skipping preprocessed_data_18069.parquet as it does not exist
# Skipping preprocessed_data_18070.parquet as it does not exist
# Skipping preprocessed_data_18071.parquet as it does not exist
# Skipping preprocessed_data_18072.parquet as it does not exist
# Skipping preprocessed_data_18073.parquet as it does not exist
# Skipping preprocessed_data_18074.parquet as it does not exist
# Skipping preprocessed_data_18075.parquet as it does not exist
# Skipping preprocessed_data_18076.parquet as it does not exist
# Skipping preprocessed_data_18077.parquet as it does not exist
# Reading and appending preprocessed_data_18078.parquet
# Skipping preprocessed_data_18079.parquet as it does not exist
# Skipping preprocessed_data_18080.parquet as it does not exist
# Skipping preprocessed_data_18081.parquet as it does not exist
# Skipping preprocessed_data_18082.parquet as it does not exist
# Skipping preprocessed_data_18083.parquet as it does not exist
# Skipping preprocessed_data_18084.parquet as it does not exist
# Skipping preprocessed_data_18085.parquet as it does not exist
# Skipping preprocessed_data_18086.parquet as it does not exist
# Skipping preprocessed_data_18087.parquet as it does not exist
# Skipping preprocessed_data_18088.parquet as it does not exist
# Skipping preprocessed_data_18089.parquet as it does not exist
# Skipping preprocessed_data_18090.parquet as it does not exist
# Skipping preprocessed_data_18091.parquet as it does not exist
# Skipping preprocessed_data_18092.parquet as it does not exist
# Reading and appending preprocessed_data_18093.parquet
# Skipping preprocessed_data_18094.parquet as it does not exist
# Skipping preprocessed_data_18095.parquet as it does not exist
# Skipping preprocessed_data_18096.parquet as it does not exist
# Skipping preprocessed_data_18097.parquet as it does not exist
# Skipping preprocessed_data_18098.parquet as it does not exist
# Skipping preprocessed_data_18099.parquet as it does not exist
# Skipping preprocessed_data_18100.parquet as it does not exist
# Skipping preprocessed_data_18101.parquet as it does not exist
# Skipping preprocessed_data_18102.parquet as it does not exist
# Skipping preprocessed_data_18103.parquet as it does not exist
# Skipping preprocessed_data_18104.parquet as it does not exist
# Skipping preprocessed_data_18105.parquet as it does not exist
# Skipping preprocessed_data_18106.parquet as it does not exist
# Skipping preprocessed_data_18107.parquet as it does not exist
# Reading and appending preprocessed_data_18108.parquet
# Skipping preprocessed_data_18109.parquet as it does not exist
# Skipping preprocessed_data_18110.parquet as it does not exist
# Skipping preprocessed_data_18111.parquet as it does not exist
# Skipping preprocessed_data_18112.parquet as it does not exist
# Skipping preprocessed_data_18113.parquet as it does not exist
# Skipping preprocessed_data_18114.parquet as it does not exist
# Skipping preprocessed_data_18115.parquet as it does not exist
# Skipping preprocessed_data_18116.parquet as it does not exist
# Skipping preprocessed_data_18117.parquet as it does not exist
# Skipping preprocessed_data_18118.parquet as it does not exist
# Skipping preprocessed_data_18119.parquet as it does not exist
# Skipping preprocessed_data_18120.parquet as it does not exist
# Skipping preprocessed_data_18121.parquet as it does not exist
# Skipping preprocessed_data_18122.parquet as it does not exist
# Reading and appending preprocessed_data_18123.parquet
# Reading and appending preprocessed_data_18124.parquet
# Reading and appending preprocessed_data_18125.parquet
# Reading and appending preprocessed_data_18126.parquet
# Reading and appending preprocessed_data_18127.parquet
# Reading and appending preprocessed_data_18128.parquet
# Reading and appending preprocessed_data_18129.parquet
# Reading and appending preprocessed_data_18130.parquet
# Reading and appending preprocessed_data_18131.parquet
# Reading and appending preprocessed_data_18132.parquet
# Reading and appending preprocessed_data_18133.parquet
# Reading and appending preprocessed_data_18134.parquet
# Reading and appending preprocessed_data_18135.parquet

# %%
import networkx as nx
from scipy.spatial import Delaunay
from sklearn.neighbors import NearestNeighbors

def add_knn_edges(G, k=5):
    nodes = list(G.nodes(data=True))
    positions = [data["position"] for _, data in nodes]
    node_ids = [node_id for node_id, _ in nodes]
    
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='ball_tree').fit(positions)
    distances, indices = nbrs.kneighbors(positions)
    
    for idx, neighbors in enumerate(indices):
        current_node = node_ids[idx]
        for neighbor_idx in neighbors:
            if current_node != node_ids[neighbor_idx]:
                G.add_edge(current_node, node_ids[neighbor_idx])

def add_delaunay_edges(G):
    nodes = list(G.nodes(data=True))
    positions = [data["position"] for _, data in nodes]
    node_ids = [node_id for node_id, _ in nodes]
    
    delaunay = Delaunay(positions)
    for simplex in delaunay.simplices:
        for i in range(simplex.size):
            for j in range(i + 1, simplex.size):
                G.add_edge(node_ids[simplex[i]], node_ids[simplex[j]])
def create_graph_from_features(features, additional_features):
    laplacian_features, hessian_features, segmented_images = features

    # Create an empty graph
    G = nx.Graph()

    # Create nodes from Laplacian features and Hessian features
    for layer_idx, (laplacian_layer, hessian_layer) in enumerate(zip(laplacian_features, hessian_features)):
        for laplacian_feature in laplacian_layer:
            node_id = f"L_{layer_idx}_{laplacian_feature[0]}_{laplacian_feature[1]}"
            G.add_node(node_id, feature_type="laplacian", layer=layer_idx, position=tuple(laplacian_feature), features=[1, 0])  # Add node features as a list

        for hessian_feature in hessian_layer:
            node_id = f"H_{layer_idx}_{hessian_feature[0]}_{hessian_feature[1]}"
            G.add_node(node_id, feature_type="hessian", layer=layer_idx, position=tuple(hessian_feature), features=[0, 1])  # Add node features as a list

    # Add global features (mean transverse momentum and mass) as graph attributes
    G.graph["mean_transverse_momentum"] = additional_features[0]
    G.graph["mass"] = additional_features[1]

    # Add k-NN edges
    add_knn_edges(G, k=5)

    # Add Delaunay edges
    add_delaunay_edges(G)

    return G

# %%
from networkx.readwrite import json_graph

graph_output_folder = '/content/drive/MyDrive/GSoC/task_3/graph_data/new/jet0_run2_graph_data'
os.makedirs(graph_output_folder, exist_ok=True)

jet_graphs = []
for idx, (jet_features, add_features) in enumerate(preprocessed_data):
    jet_graph = create_graph_from_features(jet_features, add_features)
    jet_graphs.append(jet_graph)
    
    # Convert the graph to JSON data
    graph_json_data = json_graph.node_link_data(jet_graph)
    
    # Save the JSON data to a file
    with open(os.path.join(graph_output_folder, f'graph_data_{idx}.json'), 'w') as f:
        json.dump(graph_json_data, f)

# %%
# !pip install spektral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spektral
#   Downloading spektral-1.2.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from spektral) (1.2.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from spektral) (3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from spektral) (1.4.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from spektral) (4.65.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from spektral) (4.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from spektral) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from spektral) (1.1.1)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from spektral) (2.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from spektral) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from spektral) (1.22.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (1.53.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (4.5.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (0.32.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (2.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (3.20.3)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (0.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (67.6.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (23.3.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (23.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (16.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (3.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->spektral) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->spektral) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->spektral) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->spektral) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->spektral) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->spektral) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->spektral) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->spektral) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2.0->spektral) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.2.0->spektral) (0.0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (2.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (0.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow>=2.2.0->spektral) (3.2.2)
# Installing collected packages: spektral
# Successfully installed spektral-1.2.0

# %%
def create_spektral_graph(G):
    # Extract the node attributes
    node_attrs = {attr: np.array([d[attr] for _, d in G.nodes(data=True)]) for attr in ["position", "features"]}
    x = node_attrs["features"].astype(np.float32)  # Use node features as input features
    
    # Extract the adjacency matrix and edge attributes
    a = nx.adjacency_matrix(G).astype(np.float32)
    
    return Graph(x=x, a=a)

# %%
import tensorflow as tf
import spektral
from spektral.layers import GATConv, ChebConv, GlobalAvgPool
from spektral.data import BatchLoader, Dataset, Graph
from sklearn.model_selection import train_test_split

class CustomDataset(Dataset):
    def __init__(self, graphs, **kwargs):
        self.graphs = graphs
        super().__init__(**kwargs)

    def read(self):
        return self.graphs

    def __len__(self):
        return len(self.graphs)

class CustomBatchLoader(BatchLoader):
    def __init__(self, dataset, labels, batch_size, **kwargs):
        self.labels = labels
        super().__init__(dataset, batch_size=batch_size, **kwargs)

    def load(self):
        while True:  # Add while loop to repeat data loading for multiple epochs
            index = 0
            batch_counter = 0
            current_batch = []
            for graph in self.dataset:
                current_batch.append(graph)
                batch_counter += 1
                
                if batch_counter == self.batch_size:
                    batch = self.collate(current_batch)
                    x, a = batch  # Unpack the tuple
                    y = self.labels[index:index + self.batch_size]
                    index += self.batch_size
                    y = y.reshape(-1, 1)  # Reshape the labels to (batch_size, 1)
                    yield (x, a), y
                    
                    batch_counter = 0
                    current_batch = []

# Convert the jet_graphs to a Spektral Graph list
spektral_graphs = [create_spektral_graph(g) for g in jet_graphs]

# Split the data into training and testing sets
train_graph_list, test_graph_list, y_train, y_test = train_test_split(spektral_graphs, y_processed, test_size=0.2)

# Create CustomDataset objects for training and testing
train_dataset = CustomDataset(train_graph_list)
test_dataset = CustomDataset(test_graph_list)

# Create the CustomBatchLoaders for training and testing
batch_size = 32
train_loader = CustomBatchLoader(train_dataset, y_train, batch_size=batch_size)
test_loader = CustomBatchLoader(test_dataset, y_test, batch_size=batch_size)

# %%
# Define the JetClassifier using the Keras functional API
def build_jet_classifier():
    x_in = tf.keras.Input(shape=(None, 2), name="X")  # Change input shape to (None, 2)
    a_in = tf.keras.Input(shape=(None, None), sparse=True, name="A")

    x = GATConv(32, attn_heads=4, concat_heads=True)([x_in, a_in])
    x = GATConv(64, attn_heads=4, concat_heads=True)([x, a_in])
    x = GATConv(128, attn_heads=4, concat_heads=True)([x, a_in])

    x = ChebConv(128, K=2)([x, a_in])
    x = ChebConv(64, K=2)([x, a_in])
    x = ChebConv(32, K=2)([x, a_in])

    x = GlobalAvgPool()(x)
    x = tf.keras.layers.Dense(256, activation="gelu")(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(128, activation="relu")(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs=[x_in, a_in], outputs=x)

    return model

# Instantiate the model
model = build_jet_classifier()

# Compile the model
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),  # Change the loss function to BinaryCrossentropy
              metrics=["accuracy"])

model.summary()
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X (InputLayer)                 [(None, None, 2)]    0           []
#
#  A (InputLayer)                 [(None, None, None)  0           []
#                                 ]
#
#  gat_conv (GATConv)             (None, None, 128)    640         ['X[0][0]',
#                                                                   'A[0][0]']
#
#  gat_conv_1 (GATConv)           (None, None, 256)    33536       ['gat_conv[0][0]',
#                                                                   'A[0][0]']
#
#  gat_conv_2 (GATConv)           (None, None, 512)    132608      ['gat_conv_1[0][0]',
#                                                                   'A[0][0]']
#
#  cheb_conv (ChebConv)           (None, None, 128)    131200      ['gat_conv_2[0][0]',
#                                                                   'A[0][0]']
#
#  cheb_conv_1 (ChebConv)         (None, None, 64)     16448       ['cheb_conv[0][0]',
#                                                                   'A[0][0]']
#
#  cheb_conv_2 (ChebConv)         (None, None, 32)     4128        ['cheb_conv_1[0][0]',
#                                                                   'A[0][0]']
#
#  global_avg_pool (GlobalAvgPool  (None, 32)          0           ['cheb_conv_2[0][0]']
#  )
#
#  dense (Dense)                  (None, 256)          8448        ['global_avg_pool[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 360,033
# Trainable params: 360,033
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
epochs = 20
history = model.fit(
    train_loader.load(),
    steps_per_epoch=train_loader.steps_per_epoch,
    epochs=epochs,
    validation_data=test_loader.load(),
    validation_steps=test_loader.steps_per_epoch,
)
# Out:
# Epoch 1/20
# 387/387 [==============================] - 241s 615ms/step - loss: 0.7689 - accuracy: 0.5229 - val_loss: 0.6790 - val_accuracy: 0.5551
# Epoch 2/20
# 387/387 [==============================] - 232s 600ms/step - loss: 0.6909 - accuracy: 0.5539 - val_loss: 0.6738 - val_accuracy: 0.5609
# Epoch 3/20
# 387/387 [==============================] - 231s 596ms/step - loss: 0.6952 - accuracy: 0.5776 - val_loss: 0.6657 - val_accuracy: 0.5963
# Epoch 4/20
# 387/387 [==============================] - 230s 595ms/step - loss: 0.6769 - accuracy: 0.5782 - val_loss: 0.6640 - val_accuracy: 0.6066
# Epoch 5/20
# 387/387 [==============================] - 232s 600ms/step - loss: 0.6741 - accuracy: 0.5858 - val_loss: 0.6596 - val_accuracy: 0.5947
# Epoch 6/20
# 387/387 [==============================] - 230s 595ms/step - loss: 0.6733 - accuracy: 0.5926 - val_loss: 0.6578 - val_accuracy: 0.6066
# Epoch 7/20
# 387/387 [==============================] - 231s 598ms/step - loss: 0.6716 - accuracy: 0.5962 - val_loss: 0.6654 - val_accuracy: 0.5892
# Epoch 8/20
# 387/387 [==============================] - 231s 597ms/step - loss: 0.6712 - accuracy: 0.5914 - val_loss: 0.6578 - val_accuracy: 0.6047
# Epoch 9/20
# 387/387 [==============================] - 230s 593ms/step - loss: 0.6698 - accuracy: 0.5919 - val_loss: 0.8921 - val_accuracy: 0.5184
# Epoch 10/20
# 387/387 [==============================] - 233s 601ms/step - loss: 0.6710 - accuracy: 0.5915 - val_loss: 0.6577 - val_accuracy: 0.5957
# Epoch 11/20
# 387/387 [==============================] - 231s 598ms/step - loss: 0.6703 - accuracy: 0.5923 - val_loss: 0.6533 - val_accuracy: 0.6066
# Epoch 12/20
# 387/387 [==============================] - 233s 602ms/step - loss: 0.6690 - accuracy: 0.5938 - val_loss: 0.6560 - val_accuracy: 0.6057
# Epoch 13/20
# 387/387 [==============================] - 231s 598ms/step - loss: 0.6715 - accuracy: 0.5917 - val_loss: 0.6551 - val_accuracy: 0.6050
# Epoch 14/20
# 387/387 [==============================] - 229s 591ms/step - loss: 0.6689 - accuracy: 0.5943 - val_loss: 0.6537 - val_accuracy: 0.6037
# Epoch 15/20
# 387/387 [==============================] - 230s 594ms/step - loss: 0.6685 - accuracy: 0.5941 - val_loss: 0.6525 - val_accuracy: 0.6063
# Epoch 16/20
# 387/387 [==============================] - 232s 599ms/step - loss: 0.6672 - accuracy: 0.5950 - val_loss: 0.6521 - val_accuracy: 0.6086
# Epoch 17/20
# 387/387 [==============================] - 231s 598ms/step - loss: 0.6686 - accuracy: 0.5953 - val_loss: 0.6580 - val_accuracy: 0.5973
# Epoch 18/20
# 387/387 [==============================] - 231s 598ms/step - loss: 0.6678 - accuracy: 0.5971 - val_loss: 0.6536 - val_accuracy: 0.6089
# Epoch 19/20
# 387/387 [==============================] - 227s 588ms/step - loss: 0.6678 - accuracy: 0.5959 - val_loss: 0.6533 - val_accuracy: 0.6060
# Epoch 20/20
# 387/387 [==============================] - 230s 595ms/step - loss: 0.6671 - accuracy: 0.5970 - val_loss: 0.6525 - val_accuracy: 0.6076

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_loader.load(), steps=test_loader.steps_per_epoch)
# Out:
# 97/97 [==============================] - 19s 192ms/step - loss: 0.6528 - accuracy: 0.6066

# %%
model.save_weights('/content/drive/MyDrive/GSoC/task_3/model/model_jet0_run2_weights.h5')

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.figure()
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Plot training and validation loss
plt.figure()
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
def load(self, repeat=False):
    while True:
        index = 0
        batch_counter = 0
        current_batch = []
        for graph in self.dataset:
            current_batch.append(graph)
            batch_counter += 1

            if batch_counter == self.batch_size:
                batch = self.collate(current_batch)
                x, a = batch
                y = self.labels[index:index + self.batch_size]
                index += self.batch_size
                y = y.reshape(-1, 1)
                yield (x, a), y

                batch_counter = 0
                current_batch = []

        if not repeat:
            break

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Create a CustomBatchLoader with batch_size=1 for predictions
pred_loader = CustomBatchLoader(test_dataset, y_test, batch_size=1)

# Get predictions
y_pred = model.predict(pred_loader.load(), steps=pred_loader.steps_per_epoch)
y_pred = y_pred.squeeze()

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, y_pred)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, label="ROC curve (area = %0.2f)" % roc_auc)
plt.plot([0, 1], [0, 1], "k--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC)")
plt.legend(loc="lower right")
plt.show()
# Out:
# 3090/3090 [==============================] - 26s 8ms/step
